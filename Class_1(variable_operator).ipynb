# %% [markdown]
# # Arithmetic operator

# %%
#operators - +,-,*,/  operands - 1,2,3,4
#Addition
c=2+3
c
# Out:
# 5

# %%
#Subtraction
a=5-1
a
# Out:
# 4

# %%
#Multplication
b=7*2
b
# Out:
# 14

# %%
#Division
c=8/3
c
# Out:
# 2.6666666666666665

# %%
#Answer in integer
d=8//3
d
# Out:
# 2

# %%
#Remainder
b=7%2
b
# Out:
# 1

# %%
#Power
a=2**3
a
# Out:
# 8

# %%
#Root_over
16**(1/4)
# Out:
# 2.0

# %% [markdown]
# # Variables

# %%
#first element must be alphabet/underscore
#in middle/ending - alphabet/number/underscore
a2=10
a2
# Out:
# 10

# %%
_a2=20
_a2
# Out:
# 20

# %%
a_2=30
a_2
# Out:
# 30

# %%
a2_=40
a2_
# Out:
# 40

# %%
#Variable names are case sensetive
a=5
A=10
a,A
# Out:
# (5, 10)

# %%
#Value assign in separate lines
b=4
c=5
b,c
# Out:
# (4, 5)

# %%
#Value assign in same line
b,c=6,7
b,c
# Out:
# (6, 7)

# %%
#Assignment operator - +=,-=,/=
a=5
a+=2
b=6
b-=3
c=8
c//=2
d=3
d**=2
a,b,c,d
# Out:
# (7, 3, 4, 9)

# %%
#Comparison Operator - <,>,<=,>=,!
a,b=5,10
#or and - instead of symbol need to use word
a==b or a<b
#a<=b
# Out:
# True

# %%
b,c=1,10
b==c and b>c
#b>=c
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#not - answer will be reserved
not a!=b
# Out:
# False

# %%
#is/is not - normal sentence
b is c
# Out:
# False

# %%
b is not c
# Out:
# True

# %%
#in/in not - a number is present or not
5 in (1,2,3,4,5)
# Out:
# True

# %%
5 not in (1,2,3,4,5)
# Out:
# False
