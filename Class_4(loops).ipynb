# %%
list1 = [2,6,8,10,13]
for ele in list1:
    print(ele)
    index = list1.index(ele)
    list1[index] = ele**2
list1
# Out:
# 2
# 6
# 8
# 10
# 13
# [4, 36, 64, 100, 169]

# %%
list2 = [3,5,7,9]
for i in range(len(list2)):
    print(i)
    #print(list2[i])
    list2[i] = list2[i]**2
list2
# Out:
# 0
# 1
# 2
# 3
# [9, 25, 49, 81]

# %%
list3= [2,4,6,8]
list4 = []
for element in list3:
    list4.append(element**2)
list4
# Out:
# [4, 16, 36, 64]

# %%
list3 = [2,3,4,5]
sum1 = 0
for ele in list3:
    sum1 +=ele
sum1
# Out:
# 14

# %%
#print index and items
list5 = [4,7,2,9,6]
for element in range(len(list5)):
    print(list5[element],element)
# Out:
# 4 0
# 7 1
# 2 2
# 9 3
# 6 4

# %%
n = int(input('num: '))
fac = 1
for i in range(1,n+1):
    print(i)
    fac*=i
print(fac)
# Out:
# num: 3
# 1
# 2
# 3
# 6

# %%
list6 = [1,2,3,4,5,6,7,8,9,0]
for element in list6:
    if element%2==0:
        print(element," is even")
    else:
        print(element," is odd")
# Out:
# 1  is odd
# 2  is even
# 3  is odd
# 4  is even
# 5  is odd
# 6  is even
# 7  is odd
# 8  is even
# 9  is odd
# 0  is even
